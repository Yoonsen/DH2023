# %%
import dhlab as dh

# %%
c = dh.Corpus(author="Hamsun", title="markens")

# %%
c
# Out:
#      dhlabid                                  urn                  title  \
# 0  100371490  URN:NBN:no-nb_digibok_2018041848119          Markens grøde
# 1  100344962  URN:NBN:no-nb_digibok_2017082148027          Markens grøde
# 2  100374217  URN:NBN:no-nb_digibok_2018062105001          Markens grøde
# 3  100117979  URN:NBN:no-nb_digibok_2012103108074          Markens grøde
# 4  100253852  URN:NBN:no-nb_digibok_2015062308118          Markens grøde
# 5  100447029  URN:NBN:no-nb_digibok_2009020304077          Markens grøde
# 6  100336070  URN:NBN:no-nb_digibok_2017060748095          Markens grøde
# 7  100325482  URN:NBN:no-nb_digibok_2017022048559  Markens grøde : roman
# 8  100586277  URN:NBN:no-nb_digibok_2021120148028          Markens grøde
# 9  100344137  URN:NBN:no-nb_digibok_2017081548076          Markens grøde
#
#                                              authors  \
# 0  Hartmann , Sebastian / Hamsun , Knut / Tørress...
# 1                                      Hamsun , Knut
# ...

# %%
dh.Concordance(c, "Isak AND (ham OR han OR henne OR hun)").show(100)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c18e9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c18e9_level0_col0" class="col_heading level0 col0" >link</th>
#       <th id="T_c18e9_level0_col1" class="col_heading level0 col1" >concordance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c18e9_level0_row0" class="row_heading level0 row0" >731</th>
#       <td id="T_c18e9_row0_col0" class="data row0 col0" ><a target='_blank' href = 'https://urn.nb.no/URN:NBN:no-nb_digibok_2012103108074'>URN:NBN:no-nb_digibok_2012103108074</a></td>
#       <td id="T_c18e9_row0_col1" class="data row0 col1" >Du blev kjøper av stedet hans Brede , sa <b>Isak</b> , skal du bruke det ? — Nei jeg skal ikke... </td>
#     </tr>
#     <tr>
#       <th id="T_c18e9_level0_row1" class="row_heading level0 row1" >1423</th>
# ...

# %%
import spacy

# %%
p = nlp("Saa blev det et andet Liv for den ensomme Mand.")

# %%
spacy.displacy.render(p)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="nb" id="332d6d140dc34172bc7fd4cc73883f27-0" class="displacy" width="1800" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Saa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">blev</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
# ...

# %%
from pathlib import Path

#nlp = spacy.load('en_core_web_sm', parse=True, tag=True, entity=True)

svg = spacy.displacy.render(p, style="dep", page=True)

#output_path = Path("dependency_plot.svg") # you can keep there only "dependency_plot.svg" if you want to save it in the same folder where you run the script 
#output_path.open("w", encoding="utf-8").write(svg)
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="nb">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="nb" id="b56c9a383dee424d898151c2888e8c7e-0" class="displacy" width="1800" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Saa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# ...

# %%
dh.Chunks()
# Out:
# None
